# %%
import numpy as np

import math

import matplotlib.pyplot as plt
from scipy import stats

from scipy.stats import norm


import seaborn as sns
sns.set(style="white", palette="muted", color_codes=True)
sns.set_style('ticks')
sns.set_context("talk", rc={"lines.linewidth": 4}, font_scale=1.25)


tyear=3.15551e+07


au=1.5e11
msun=2e30
mearth=5.97e24
grav=6.67e-11

from astropy.io import ascii


import re


label=[ 'a=1mm, fv=0.5', 'a=1um, fv=0.2', 'a=1mm, fv=0.5 noresurf']

dir1='your_dir/'


color_all=['tab:blue','tab:olive', 'tab:orange', 'tab:red', 'tab:purple', 'tab:green', 'k']

#230300

#########

# %%
   
fig, ax = plt.subplots(figsize=(10, 6))



alpha_r=-3.5
delta = 0.01
eta=0.5
alpha = (alpha_r+3)/2.
print('alpha', alpha)



# now add analytic form from Mark's 2011 paper

#  Eq 20 

# 
eta_max=eta**(1./3.)

delta_d= (delta/3)**(1./3.)
delta_d=delta
print('d', delta_d)



k_i=np.arange(0,1000000)

#f_s_mark=eta_max**(alpha_r-4)* (4-alpha_r)*delta_d*(1-delta_d)**((4-alpha_r)*k_i)

#plt.plot(k_i, f_s_mark, linestyle=':', label='Mark')



f_s=eta**(alpha-1)* (1-alpha)*delta*(1-delta)**((1-alpha)*k_i)
plt.plot(k_i/3., f_s)

#alpha=11./6.-1
#f_s=eta**(alpha-1)* (1-alpha)*delta*(1-delta)**((1-alpha)*k_i)
#plt.plot(k_i/3., f_s, linestyle='dashdot', label='\alpha=5/6')



delta=0.2
f_s=eta**(alpha-1)* (1-alpha)*delta*(1-delta)**((1-alpha)*k_i)
#plt.plot(k_i/3., f_s, linestyle='dashdot', label='0.2')



ax.legend()
ax.set_yscale('log')

plt.xlabel('k-i')
plt.ylabel('$F_s$(k-i)')
ax.set_xlim((1,500))
ax.set_ylim((1e-11,0.1))

plt.savefig(dir1+"plot_fs.pdf")
# Out:
# No handles with labels found to put in legend.
# alpha -0.25
# d 0.01

# %%
   
fig, ax = plt.subplots(figsize=(10, 6))



alpha_r=-3.5
delta = 0.01
eta=0.5
alpha = (alpha_r+3)/2.
print('alpha', alpha)



# now add analytic form from Mark's 2011 paper

#  Eq 20 

# 
eta_max=eta**(1./3.)

delta_d= (delta/3)**(1./3.)
delta_d=delta
print('d', delta_d)



k_i=np.arange(0,1000000)

#f_s_mark=eta_max**(alpha_r-4)* (4-alpha_r)*delta_d*(1-delta_d)**((4-alpha_r)*k_i)

#plt.plot(k_i, f_s_mark, linestyle=':', label='Mark')



f_s=eta**(alpha-1)* (1-alpha)*delta*(1-delta)**((1-alpha)*k_i)
plt.plot(k_i/3., f_s)

#alpha=11./6.-1
#f_s=eta**(alpha-1)* (1-alpha)*delta*(1-delta)**((1-alpha)*k_i)
#plt.plot(k_i/3., f_s, linestyle='dashdot', label='\alpha=5/6')



delta=0.2
f_s=eta**(alpha-1)* (1-alpha)*delta*(1-delta)**((1-alpha)*k_i)
#plt.plot(k_i/3., f_s, linestyle='dashdot', label='0.2')



ax.legend()
ax.set_yscale('log')

plt.xlabel('k-i')
plt.ylabel('$F_s$(k-i)')
ax.set_xlim((1,500))
ax.set_ylim((1e-11,0.1))

plt.savefig(dir1+"plot_fs.pdf")
# Out:
# No handles with labels found to put in legend.
# alpha -0.25
# d 0.01
